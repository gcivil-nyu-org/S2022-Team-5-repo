# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
manhattan2020 = pd.read_csv('2020/2020_manhattan.csv')
manhattan2019 = pd.read_csv('2019/2019_manhattan.csv')
manhattan2018 = pd.read_csv('2018/2018_manhattan.csv')
manhattan2017 = pd.read_csv('2017/2017_manhattan.csv')
manhattan2016 = pd.read_csv('2016/2016_manhattan.csv')

# %%
manhattan2021 = pd.read_csv('2021/2021_manhattan.csv')

# %%
manhattan2020.columns = ['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE', 'SALE PRICE', 'SALE DATE']

# %%
manhattan2016.columns = manhattan2020.columns
manhattan2017.columns = manhattan2020.columns
manhattan2018.columns = manhattan2020.columns
manhattan2019.columns = manhattan2020.columns

# %%
manhattan2021.columns = manhattan2020.columns

# %%
manhattan2021 = manhattan2021.drop(['BOROUGH','BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE','SALE DATE'], axis = 1)

# %%
manhattan2016 = manhattan2016.drop(['BOROUGH','BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE','SALE DATE'], axis = 1)

# %%
manhattan2017 = manhattan2017.drop(['BOROUGH','BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE','SALE DATE'], axis = 1)

# %%
manhattan2018 = manhattan2018.drop(['BOROUGH','BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE','SALE DATE'], axis = 1)

# %%
manhattan2019 = manhattan2019.drop(['BOROUGH','BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE','SALE DATE'], axis = 1)

# %%
manhattan2020 = manhattan2020.drop(['BOROUGH','BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE','SALE DATE'], axis = 1)

# %%
manhattan2016['SALE PRICE'] = manhattan2016['SALE PRICE'].astype(str)
manhattan2017['SALE PRICE'] = manhattan2017['SALE PRICE'].astype(str)
manhattan2018['SALE PRICE'] = manhattan2018['SALE PRICE'].astype(str)
manhattan2019['SALE PRICE'] = manhattan2019['SALE PRICE'].astype(str)
manhattan2020['SALE PRICE'] = manhattan2020['SALE PRICE'].astype(str)

# %%
manhattan2021['SALE PRICE'] = manhattan2021['SALE PRICE'].astype(str)

# %%
manhattan2016['SALE PRICE'] = manhattan2016['SALE PRICE'].apply(lambda x: x.replace(',', ''))
manhattan2017['SALE PRICE'] = manhattan2017['SALE PRICE'].apply(lambda x: x.replace(',', ''))
manhattan2018['SALE PRICE'] = manhattan2018['SALE PRICE'].apply(lambda x: x.replace(',', ''))
manhattan2019['SALE PRICE'] = manhattan2019['SALE PRICE'].apply(lambda x: x.replace(',', ''))
manhattan2020['SALE PRICE'] = manhattan2020['SALE PRICE'].apply(lambda x: x.replace(',', ''))

# %%
manhattan2021['SALE PRICE'] = manhattan2021['SALE PRICE'].apply(lambda x: x.replace(',', ''))

# %%
manhattan2016['SALE PRICE'] = manhattan2016['SALE PRICE'].replace(' ', '0')
manhattan2017['SALE PRICE'] = manhattan2017['SALE PRICE'].replace(' ', '0')
manhattan2018['SALE PRICE'] = manhattan2018['SALE PRICE'].replace(' ', '0')
manhattan2019['SALE PRICE'] = manhattan2019['SALE PRICE'].replace(' ', '0')
manhattan2020['SALE PRICE'] = manhattan2020['SALE PRICE'].replace(' ', '0')

# %%
manhattan2021['SALE PRICE'] = manhattan2021['SALE PRICE'].replace(' ', '0')

# %%
manhattan2016['SALE PRICE'] = manhattan2016['SALE PRICE'].replace(' -   ', '0')
manhattan2017['SALE PRICE'] = manhattan2017['SALE PRICE'].replace(' -   ', '0')
manhattan2018['SALE PRICE'] = manhattan2018['SALE PRICE'].replace(' -   ', '0')
manhattan2019['SALE PRICE'] = manhattan2019['SALE PRICE'].replace(' -   ', '0')
manhattan2020['SALE PRICE'] = manhattan2020['SALE PRICE'].replace(' -   ', '0')

# %%
manhattan2021['SALE PRICE'] = manhattan2021['SALE PRICE'].replace(' -   ', '0')

# %%
manhattan2016['SALE PRICE'] = pd.to_numeric(manhattan2016['SALE PRICE'], errors = 'coerce')
manhattan2017['SALE PRICE'] = pd.to_numeric(manhattan2017['SALE PRICE'], errors = 'coerce')
manhattan2018['SALE PRICE'] = pd.to_numeric(manhattan2018['SALE PRICE'], errors = 'coerce')
manhattan2019['SALE PRICE'] = pd.to_numeric(manhattan2019['SALE PRICE'], errors = 'coerce')
manhattan2020['SALE PRICE'] = pd.to_numeric(manhattan2020['SALE PRICE'], errors = 'coerce')

# %%
manhattan2021['SALE PRICE'] = pd.to_numeric(manhattan2021['SALE PRICE'], errors = 'coerce')

# %%
manhattan2020['SALE PRICE'].isna().sum()
# Out:
# 8830

# %%
manhattan2016['SALE PRICE'].unique()
# Out:
# array([ 7738700,        0,  6350000, ...,   440482,   471815, 26300000])

# %%
manhattan2016.dropna(inplace = True)
manhattan2017.dropna(inplace = True)
manhattan2018.dropna(inplace = True)
manhattan2019.dropna(inplace = True)
manhattan2020.dropna(inplace = True)

# %%
manhattan2021.dropna(inplace = True)

# %%
manhattan2016['SALE PRICE'] = manhattan2016['SALE PRICE'].astype(float).div(1000000)
df2016 = manhattan2016.groupby(['NEIGHBORHOOD']).sum().reset_index()

# %%
manhattan2017['SALE PRICE'] = manhattan2017['SALE PRICE'].astype(float).div(1000000)
df2017 = manhattan2017.groupby(['NEIGHBORHOOD']).sum().reset_index()

# %%
manhattan2018['SALE PRICE'] = manhattan2018['SALE PRICE'].astype(float).div(1000000)
df2018 = manhattan2018.groupby(['NEIGHBORHOOD']).sum().reset_index()

# %%
manhattan2019['SALE PRICE'] = manhattan2019['SALE PRICE'].astype(float).div(1000000)
df2019 = manhattan2019.groupby(['NEIGHBORHOOD']).sum().reset_index()

# %%
manhattan2020['SALE PRICE'] = manhattan2020['SALE PRICE'].astype(float).div(1000000)
df2020 = manhattan2020.groupby(['NEIGHBORHOOD']).sum().reset_index()

# %%
manhattan2021['SALE PRICE'] = manhattan2021['SALE PRICE'].astype(float).div(1000000)
df2021 = manhattan2021.groupby(['NEIGHBORHOOD']).sum().reset_index()

# %%
manhattan2016['NEIGHBORHOOD'][manhattan2016['SALE PRICE'] == manhattan2016['SALE PRICE'].max()]
# Out:
# 10356    MIDTOWN WEST
# Name: NEIGHBORHOOD, dtype: object

# %%
manhattan2016.groupby(['NEIGHBORHOOD']).count()
# Out:
#                            SALE PRICE
# NEIGHBORHOOD
# ALPHABET CITY                     180
# CHELSEA                           947
# CHINATOWN                         163
# CIVIC CENTER                      325
# CLINTON                           306
# EAST VILLAGE                      173
# FASHION                           170
# FINANCIAL                         483
# FLATIRON                          467
# GRAMERCY                          556
# GREENWICH VILLAGE-CENTRAL         753
# GREENWICH VILLAGE-WEST            730
# HARLEM-CENTRAL                    826
# HARLEM-EAST                       387
# HARLEM-UPPER                      168
# HARLEM-WEST                        46
# INWOOD                            138
# JAVITS CENTER                      60
# KIPS BAY                          328
# LITTLE ITALY                       84
# LOWER EAST SIDE                   305
# MANHATTAN VALLEY                  208
# MANHATTAN-UNKNOWN                   1
# ...

# %%
manhattan2018.groupby(['NEIGHBORHOOD']).count()
# Out:
#                            SALE PRICE
# NEIGHBORHOOD
# ALPHABET CITY                     173
# CHELSEA                           664
# CHINATOWN                         142
# CIVIC CENTER                      156
# CLINTON                           317
# EAST VILLAGE                      243
# FASHION                           215
# FINANCIAL                         324
# FLATIRON                          352
# GRAMERCY                          455
# GREENWICH VILLAGE-CENTRAL         542
# GREENWICH VILLAGE-WEST            622
# HARLEM-CENTRAL                    757
# HARLEM-EAST                       213
# HARLEM-UPPER                      176
# HARLEM-WEST                        36
# INWOOD                            133
# JAVITS CENTER                      42
# KIPS BAY                          358
# LITTLE ITALY                       65
# LOWER EAST SIDE                   402
# MANHATTAN VALLEY                  251
# MIDTOWN CBD                       165
# ...

# %%
manhattan2019.groupby(['NEIGHBORHOOD']).count()
# Out:
#                            SALE PRICE
# NEIGHBORHOOD
# ALPHABET CITY                     136
# CHELSEA                           739
# CHINATOWN                         154
# CIVIC CENTER                      308
# CLINTON                           259
# EAST VILLAGE                      187
# FASHION                           143
# FINANCIAL                         306
# FLATIRON                          314
# GRAMERCY                          733
# GREENWICH VILLAGE-CENTRAL         629
# GREENWICH VILLAGE-WEST            591
# HARLEM-CENTRAL                    779
# HARLEM-EAST                       248
# HARLEM-UPPER                      136
# HARLEM-WEST                        40
# INWOOD                            122
# JAVITS CENTER                     210
# KIPS BAY                          294
# LITTLE ITALY                       65
# LOWER EAST SIDE                   625
# MANHATTAN VALLEY                  208
# MIDTOWN CBD                       226
# ...

# %%
manhattan2017.groupby(['NEIGHBORHOOD']).count()
# Out:
#                            SALE PRICE
# NEIGHBORHOOD
# ALPHABET CITY                     191
# CHELSEA                           815
# CHINATOWN                         134
# CIVIC CENTER                      285
# CLINTON                           354
# EAST VILLAGE                      180
# FASHION                           108
# FINANCIAL                         552
# FLATIRON                          499
# GRAMERCY                          441
# GREENWICH VILLAGE-CENTRAL         536
# GREENWICH VILLAGE-WEST            596
# HARLEM-CENTRAL                    854
# HARLEM-EAST                       230
# HARLEM-UPPER                      162
# HARLEM-WEST                        50
# INWOOD                            125
# JAVITS CENTER                      43
# KIPS BAY                          391
# LITTLE ITALY                       45
# LOWER EAST SIDE                   332
# MANHATTAN VALLEY                  257
# MIDTOWN CBD                       196
# ...

# %%
manhattan2021.groupby(['NEIGHBORHOOD']).count()
# Out:
#                            SALE PRICE
# NEIGHBORHOOD
# ALPHABET CITY                     142
# CHELSEA                           961
# CHINATOWN                          89
# CIVIC CENTER                      294
# CLINTON                           356
# EAST VILLAGE                      229
# FASHION                           144
# FINANCIAL                         526
# FLATIRON                          366
# GRAMERCY                          644
# GREENWICH VILLAGE-CENTRAL         799
# GREENWICH VILLAGE-WEST            736
# HARLEM-CENTRAL                    736
# HARLEM-EAST                       178
# HARLEM-UPPER                       97
# HARLEM-WEST                        35
# INWOOD                            122
# JAVITS CENTER                     104
# KIPS BAY                          397
# LITTLE ITALY                       68
# LOWER EAST SIDE                   451
# MANHATTAN VALLEY                  243
# MIDTOWN CBD                       220
# ...

# %%
manhattan2020.groupby(['NEIGHBORHOOD']).count()
# Out:
#                            SALE PRICE
# NEIGHBORHOOD
# ALPHABET CITY                     128
# CHELSEA                           496
# CHINATOWN                          63
# CIVIC CENTER                      194
# CLINTON                           200
# EAST VILLAGE                      127
# FASHION                           125
# FINANCIAL                         211
# FLATIRON                          215
# GRAMERCY                          321
# GREENWICH VILLAGE-CENTRAL         569
# GREENWICH VILLAGE-WEST            462
# HARLEM-CENTRAL                    551
# HARLEM-EAST                       171
# HARLEM-UPPER                       92
# HARLEM-WEST                        27
# INWOOD                             93
# JAVITS CENTER                      60
# KIPS BAY                          234
# LITTLE ITALY                       64
# LOWER EAST SIDE                   296
# MANHATTAN VALLEY                  191
# MIDTOWN CBD                       242
# ...

# %%
df2016
# Out:
#                  NEIGHBORHOOD   SALE PRICE
# 0   ALPHABET CITY               497.604641
# 1   CHELSEA                    2718.722550
# 2   CHINATOWN                   325.143892
# 3   CIVIC CENTER               1263.935058
# 4   CLINTON                     715.474308
# 5   EAST VILLAGE                408.658644
# 6   FASHION                    2831.497766
# 7   FINANCIAL                  2214.975800
# 8   FLATIRON                   1732.384557
# 9   GRAMERCY                    875.112374
# 10  GREENWICH VILLAGE-CENTRAL  2071.208653
# 11  GREENWICH VILLAGE-WEST     2566.972718
# 12  HARLEM-CENTRAL             1748.456473
# 13  HARLEM-EAST                 710.615590
# 14  HARLEM-UPPER                228.929344
# 15  HARLEM-WEST                 204.836570
# 16  INWOOD                      210.759751
# 17  JAVITS CENTER               834.577110
# 18  KIPS BAY                   1164.255717
# 19  LITTLE ITALY                290.468015
# 20  LOWER EAST SIDE             560.001483
# ...

# %%
plt.figure(figsize=(20,6))
plt.title('Manhattan Prices Comparision 2016')
plt.xlabel('Neighbourhood')
plt.ylabel('Prices in Millions')
plt.bar(df2016['NEIGHBORHOOD'],df2016['SALE PRICE'], color = (0.5,0.1,0.5,0.6))
plt.xticks(rotation=90)
plt.savefig('Manhattan Prices Comparision 2016)',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.title('Manhattan Prices Comparision 2017')
plt.xlabel('Neighbourhood')
plt.ylabel('Prices in Millions')
plt.bar(df2017['NEIGHBORHOOD'],df2017['SALE PRICE'], color = (0.5,0.1,0.5,0.6))
plt.xticks(rotation=90)
plt.savefig('Manhattan Prices Comparision 2017)',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.title('Manhattan Prices Comparision 2018')
plt.xlabel('Neighbourhood')
plt.ylabel('Prices in Millions')
plt.bar(df2018['NEIGHBORHOOD'],df2018['SALE PRICE'], color = (0.5,0.1,0.5,0.6))
plt.xticks(rotation=90)
plt.savefig('Manhattan Prices Comparision 2018)',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.title('Manhattan Prices Comparision 2019')
plt.xlabel('Neighbourhood')
plt.ylabel('Prices in Millions')
plt.bar(df2019['NEIGHBORHOOD'],df2019['SALE PRICE'], color = (0.5,0.1,0.5,0.6))
plt.xticks(rotation=90)
plt.savefig('Manhattan Prices Comparision 2019)',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.title('Manhattan Prices Comparision 2020')
plt.xlabel('Neighbourhood')
plt.ylabel('Prices in Millions')
plt.bar(df2020['NEIGHBORHOOD'],df2020['SALE PRICE'], color = (0.5,0.1,0.5,0.6))
plt.xticks(rotation=90)
plt.savefig('Manhattan Prices Comparision 2020)',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.title('Manhattan Prices Comparision 2021')
plt.xlabel('Neighbourhood')
plt.ylabel('Prices in Millions')
plt.bar(df2021['NEIGHBORHOOD'],df2021['SALE PRICE'], color = (0.5,0.1,0.5,0.6))
plt.xticks(rotation=90)
plt.savefig('Manhattan Prices Comparision 2021)',bbox_inches='tight')
plt.show()
