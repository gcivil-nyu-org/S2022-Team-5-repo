# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
queens2020 = pd.read_csv('2020/2020_queens.csv')
queens2019 = pd.read_csv('2019/2019_queens.csv')
queens2018 = pd.read_csv('2018/2018_queens.csv')
queens2017 = pd.read_csv('2017/2017_queens.csv')
queens2016 = pd.read_csv('2016/2016_queens.csv')

# %%
queens2021 = pd.read_csv('2021/2021_queens.csv')

# %%
queens2020.columns = ['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASEMENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE', 'SALE PRICE', 'SALE DATE']

# %%
queens2021.columns = ['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASEMENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE', 'SALE PRICE', 'SALE DATE']

# %%
queens2016.columns = queens2020.columns
queens2017.columns = queens2020.columns
queens2018.columns = queens2020.columns
queens2019.columns = queens2020.columns

# %%
queens2021.columns = queens2021.columns

# %%
queens2016 = queens2016.drop(['BOROUGH','BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASEMENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE','SALE DATE'], axis = 1)

# %%
queens2017 = queens2017.drop(['BOROUGH','BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASEMENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE','SALE DATE'], axis = 1)

# %%
queens2018 = queens2018.drop(['BOROUGH','BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASEMENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE','SALE DATE'], axis = 1)

# %%
queens2019 = queens2019.drop(['BOROUGH','BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASEMENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE','SALE DATE'], axis = 1)

# %%
queens2020 = queens2020.drop(['BOROUGH','BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASEMENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE','SALE DATE'], axis = 1)

# %%
queens2021 = queens2021.drop(['BOROUGH','BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASEMENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE','SALE DATE'], axis = 1)

# %%
queens2016['SALE PRICE'] = queens2016['SALE PRICE'].astype(str)
queens2017['SALE PRICE'] = queens2017['SALE PRICE'].astype(str)
queens2018['SALE PRICE'] = queens2018['SALE PRICE'].astype(str)
queens2019['SALE PRICE'] = queens2019['SALE PRICE'].astype(str)
queens2020['SALE PRICE'] = queens2020['SALE PRICE'].astype(str)

# %%
queens2021['SALE PRICE'] = queens2021['SALE PRICE'].astype(str)

# %%
queens2016['SALE PRICE'] = queens2016['SALE PRICE'].apply(lambda x: x.replace(',', ''))
queens2017['SALE PRICE'] = queens2017['SALE PRICE'].apply(lambda x: x.replace(',', ''))
queens2018['SALE PRICE'] = queens2018['SALE PRICE'].apply(lambda x: x.replace(',', ''))
queens2019['SALE PRICE'] = queens2019['SALE PRICE'].apply(lambda x: x.replace(',', ''))
queens2020['SALE PRICE'] = queens2020['SALE PRICE'].apply(lambda x: x.replace(',', ''))

# %%
queens2021['SALE PRICE'] = queens2021['SALE PRICE'].apply(lambda x: x.replace(',', ''))

# %%
queens2016['SALE PRICE'] = queens2016['SALE PRICE'].replace(' ', '0')
queens2017['SALE PRICE'] = queens2017['SALE PRICE'].replace(' ', '0')
queens2018['SALE PRICE'] = queens2018['SALE PRICE'].replace(' ', '0')
queens2019['SALE PRICE'] = queens2019['SALE PRICE'].replace(' ', '0')
queens2020['SALE PRICE'] = queens2020['SALE PRICE'].replace(' ', '0')

# %%
queens2021['SALE PRICE'] = queens2021['SALE PRICE'].replace(' ', '0')

# %%
queens2016['SALE PRICE'] = queens2016['SALE PRICE'].replace(' -   ', '0')
queens2017['SALE PRICE'] = queens2017['SALE PRICE'].replace(' -   ', '0')
queens2018['SALE PRICE'] = queens2018['SALE PRICE'].replace(' -   ', '0')
queens2019['SALE PRICE'] = queens2019['SALE PRICE'].replace(' -   ', '0')
queens2020['SALE PRICE'] = queens2020['SALE PRICE'].replace(' -   ', '0')

# %%
queens2021['SALE PRICE'] = queens2021['SALE PRICE'].replace(' -   ', '0')

# %%
queens2016['SALE PRICE'] = pd.to_numeric(queens2016['SALE PRICE'], errors = 'coerce')
queens2017['SALE PRICE'] = pd.to_numeric(queens2017['SALE PRICE'], errors = 'coerce')
queens2018['SALE PRICE'] = pd.to_numeric(queens2018['SALE PRICE'], errors = 'coerce')
queens2019['SALE PRICE'] = pd.to_numeric(queens2019['SALE PRICE'], errors = 'coerce')
queens2020['SALE PRICE'] = pd.to_numeric(queens2020['SALE PRICE'], errors = 'coerce')

# %%
queens2021['SALE PRICE'] = pd.to_numeric(queens2021['SALE PRICE'], errors = 'coerce')

# %%
queens2020['SALE PRICE'].isna().sum()
# Out:
# 9

# %%
queens2016['SALE PRICE'].unique()
# Out:
# array([7800000,  660000,  275500, ..., 2925000, 2660000, 6600000])

# %%
queens2016.dropna(inplace = True)
queens2017.dropna(inplace = True)
queens2018.dropna(inplace = True)
queens2019.dropna(inplace = True)
queens2020.dropna(inplace = True)

# %%
queens2021.dropna(inplace = True)

# %%
queens2016['SALE PRICE'] = queens2016['SALE PRICE'].astype(float).div(1000000)
df2016 = queens2016.groupby(['NEIGHBORHOOD']).sum().reset_index()

# %%
queens2017['SALE PRICE'] = queens2017['SALE PRICE'].astype(float).div(1000000)
df2017 = queens2017.groupby(['NEIGHBORHOOD']).sum().reset_index()

# %%
queens2018['SALE PRICE'] = queens2018['SALE PRICE'].astype(float).div(1000000)
df2018 = queens2018.groupby(['NEIGHBORHOOD']).sum().reset_index()

# %%
queens2019['SALE PRICE'] = queens2019['SALE PRICE'].astype(float).div(1000000)
df2019 = queens2019.groupby(['NEIGHBORHOOD']).sum().reset_index()

# %%
queens2020['SALE PRICE'] = queens2020['SALE PRICE'].astype(float).div(1000000)
df2020 = queens2020.groupby(['NEIGHBORHOOD']).sum().reset_index()

# %%
queens2021['SALE PRICE'] = queens2021['SALE PRICE'].astype(float).div(1000000)
df2021 = queens2021.groupby(['NEIGHBORHOOD']).sum().reset_index()

# %%
plt.figure(figsize=(20,6))
plt.title('Queens Prices Comparision 2016')
plt.xlabel('Neighbourhood')
plt.ylabel('Prices in Millions')
plt.bar(df2016['NEIGHBORHOOD'],df2016['SALE PRICE'], color = 'c')
plt.xticks(rotation=90)
plt.savefig('Queens Prices Comparision 2016)',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.title('Queens Prices Comparision 2017')
plt.xlabel('Neighbourhood')
plt.ylabel('Prices in Millions')
plt.bar(df2017['NEIGHBORHOOD'],df2017['SALE PRICE'], color = 'c')
plt.xticks(rotation=90)
plt.savefig('Queens Prices Comparision 2017)',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.title('Queens Prices Comparision 2018')
plt.xlabel('Neighbourhood')
plt.ylabel('Prices in Millions')
plt.bar(df2018['NEIGHBORHOOD'],df2018['SALE PRICE'], color = 'c')
plt.xticks(rotation=90)
plt.savefig('Queens Prices Comparision 2018)',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.title('Queens Prices Comparision 2019')
plt.xlabel('Neighbourhood')
plt.ylabel('Prices in Millions')
plt.bar(df2019['NEIGHBORHOOD'],df2019['SALE PRICE'], color = 'c')
plt.xticks(rotation=90)
plt.savefig('Queens Prices Comparision 2019)',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.title('Queens Prices Comparision 2020')
plt.xlabel('Neighbourhood')
plt.ylabel('Prices in Millions')
plt.bar(df2020['NEIGHBORHOOD'],df2020['SALE PRICE'], color = 'c')
plt.xticks(rotation=90)
plt.savefig('Queens Prices Comparision 2020)',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.title('Queens Prices Comparision 2021')
plt.xlabel('Neighbourhood')
plt.ylabel('Prices in Millions')
plt.bar(df2021['NEIGHBORHOOD'],df2021['SALE PRICE'], color = 'c')
plt.xticks(rotation=90)
plt.savefig('Queens Prices Comparision 2021)',bbox_inches='tight')
plt.show()
