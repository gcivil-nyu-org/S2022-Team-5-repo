# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
bronx2020 = pd.read_csv('2020/2020_bronx.csv')
bronx2019 = pd.read_csv('2019/2019_bronx.csv')
bronx2018 = pd.read_csv('2018/2018_bronx.csv')
bronx2017 = pd.read_csv('2017/2017_bronx.csv')
bronx2016 = pd.read_csv('2016/2016_bronx.csv')

# %%
bronx2021 = pd.read_csv('2021/2021_bronx.csv')

# %%
bronx2020.columns = ['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE', 'SALE PRICE', 'SALE DATE']

# %%
bronx2016.columns = bronx2020.columns
bronx2017.columns = bronx2020.columns
bronx2018.columns = bronx2020.columns
bronx2019.columns = bronx2020.columns

# %%
bronx2021.columns = bronx2020.columns

# %%
bronx2021 = bronx2021.drop(['BOROUGH','BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE','SALE DATE'], axis = 1)

# %%
bronx2016 = bronx2016.drop(['BOROUGH','BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE','SALE DATE'], axis = 1)

# %%
bronx2017 = bronx2017.drop(['BOROUGH','BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE','SALE DATE'], axis = 1)

# %%
bronx2018 = bronx2018.drop(['BOROUGH','BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE','SALE DATE'], axis = 1)

# %%
bronx2019 = bronx2019.drop(['BOROUGH','BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE','SALE DATE'], axis = 1)

# %%
bronx2020 = bronx2020.drop(['BOROUGH','BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE','SALE DATE'], axis = 1)

# %%
bronx2016['SALE PRICE'] = bronx2016['SALE PRICE'].astype(str)
bronx2017['SALE PRICE'] = bronx2017['SALE PRICE'].astype(str)
bronx2018['SALE PRICE'] = bronx2018['SALE PRICE'].astype(str)
bronx2019['SALE PRICE'] = bronx2019['SALE PRICE'].astype(str)
bronx2020['SALE PRICE'] = bronx2020['SALE PRICE'].astype(str)

# %%
bronx2021['SALE PRICE'] = bronx2021['SALE PRICE'].astype(str)

# %%
bronx2016['SALE PRICE'] = bronx2016['SALE PRICE'].apply(lambda x: x.replace(',', ''))
bronx2017['SALE PRICE'] = bronx2017['SALE PRICE'].apply(lambda x: x.replace(',', ''))
bronx2018['SALE PRICE'] = bronx2018['SALE PRICE'].apply(lambda x: x.replace(',', ''))
bronx2019['SALE PRICE'] = bronx2019['SALE PRICE'].apply(lambda x: x.replace(',', ''))
bronx2020['SALE PRICE'] = bronx2020['SALE PRICE'].apply(lambda x: x.replace(',', ''))

# %%
bronx2021['SALE PRICE'] = bronx2021['SALE PRICE'].apply(lambda x: x.replace(',', ''))

# %%
bronx2016['SALE PRICE'] = bronx2016['SALE PRICE'].replace(' ', '0')
bronx2017['SALE PRICE'] = bronx2017['SALE PRICE'].replace(' ', '0')
bronx2018['SALE PRICE'] = bronx2018['SALE PRICE'].replace(' ', '0')
bronx2019['SALE PRICE'] = bronx2019['SALE PRICE'].replace(' ', '0')
bronx2020['SALE PRICE'] = bronx2020['SALE PRICE'].replace(' ', '0')

# %%
bronx2021['SALE PRICE'] = bronx2021['SALE PRICE'].replace(' ', '0')

# %%
bronx2016['SALE PRICE'] = bronx2016['SALE PRICE'].replace(' -   ', '0')
bronx2017['SALE PRICE'] = bronx2017['SALE PRICE'].replace(' -   ', '0')
bronx2018['SALE PRICE'] = bronx2018['SALE PRICE'].replace(' -   ', '0')
bronx2019['SALE PRICE'] = bronx2019['SALE PRICE'].replace(' -   ', '0')
bronx2020['SALE PRICE'] = bronx2020['SALE PRICE'].replace(' -   ', '0')

# %%
bronx2021['SALE PRICE'] = bronx2021['SALE PRICE'].replace(' -   ', '0')

# %%
bronx2016['SALE PRICE'] = pd.to_numeric(bronx2016['SALE PRICE'], errors = 'coerce')
bronx2017['SALE PRICE'] = pd.to_numeric(bronx2017['SALE PRICE'], errors = 'coerce')
bronx2018['SALE PRICE'] = pd.to_numeric(bronx2018['SALE PRICE'], errors = 'coerce')
bronx2019['SALE PRICE'] = pd.to_numeric(bronx2019['SALE PRICE'], errors = 'coerce')
bronx2020['SALE PRICE'] = pd.to_numeric(bronx2020['SALE PRICE'], errors = 'coerce')

# %%
bronx2021['SALE PRICE'] = pd.to_numeric(bronx2020['SALE PRICE'], errors = 'coerce')

# %%
bronx2020['SALE PRICE'].isna().sum()
# Out:
# 15065

# %%
bronx2016['SALE PRICE'].unique()
# Out:
# array([     0., 220000., 273796., ..., 160664., 198147.,     nan])

# %%
bronx2016.dropna(inplace = True)
bronx2017.dropna(inplace = True)
bronx2018.dropna(inplace = True)
bronx2019.dropna(inplace = True)
bronx2020.dropna(inplace = True)

# %%
bronx2021.dropna(inplace = True)

# %%
bronx2016['SALE PRICE'] = bronx2016['SALE PRICE'].astype(float).div(1000000)
df2016 = bronx2016.groupby(['NEIGHBORHOOD']).sum().reset_index()

# %%
bronx2017['SALE PRICE'] = bronx2017['SALE PRICE'].astype(float).div(1000000)
df2017 = bronx2017.groupby(['NEIGHBORHOOD']).sum().reset_index()

# %%
bronx2018['SALE PRICE'] = bronx2018['SALE PRICE'].astype(float).div(1000000)
df2018 = bronx2018.groupby(['NEIGHBORHOOD']).sum().reset_index()

# %%
bronx2019['SALE PRICE'] = bronx2019['SALE PRICE'].astype(float).div(1000000)
df2019 = bronx2019.groupby(['NEIGHBORHOOD']).sum().reset_index()

# %%
bronx2020['SALE PRICE'] = bronx2020['SALE PRICE'].astype(float).div(1000000)
df2020 = bronx2020.groupby(['NEIGHBORHOOD']).sum().reset_index()

# %%
bronx2021['SALE PRICE'] = bronx2021['SALE PRICE'].astype(float).div(1000000)
df2021 = bronx2021.groupby(['NEIGHBORHOOD']).sum().reset_index()

# %%
plt.figure(figsize=(20,6))
plt.title('Bronx Prices Comparision 2016')
plt.xlabel('Neighbourhood')
plt.ylabel('Prices in Millions')
plt.bar(df2016['NEIGHBORHOOD'],df2016['SALE PRICE'], color = 'g')
plt.xticks(rotation=90)
plt.savefig('Bronx Prices Comparision 2016)',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.title('Bronx Prices Comparision 2017')
plt.xlabel('Neighbourhood')
plt.ylabel('Prices in Millions')
plt.bar(df2017['NEIGHBORHOOD'],df2017['SALE PRICE'], color = 'g')
plt.xticks(rotation=90)
plt.savefig('Bronx Prices Comparision 2017)',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.title('Bronx Prices Comparision 2018')
plt.xlabel('Neighbourhood')
plt.ylabel('Prices in Millions')
plt.bar(df2018['NEIGHBORHOOD'],df2018['SALE PRICE'], color = 'g')
plt.xticks(rotation=90)
plt.savefig('Bronx Prices Comparision 2018)',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.title('Bronx Prices Comparision 2019')
plt.xlabel('Neighbourhood')
plt.ylabel('Prices in Millions')
plt.bar(df2019['NEIGHBORHOOD'],df2019['SALE PRICE'], color = 'g')
plt.xticks(rotation=90)
plt.savefig('Bronx Prices Comparision 2019)',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.title('Bronx Prices Comparision 2020')
plt.xlabel('Neighbourhood')
plt.ylabel('Prices in Millions')
plt.bar(df2020['NEIGHBORHOOD'],df2020['SALE PRICE'], color = 'g')
plt.xticks(rotation=90)
plt.savefig('Bronx Prices Comparision 2020)',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.title('Bronx Prices Comparision 2021')
plt.xlabel('Neighbourhood')
plt.ylabel('Prices in Millions')
plt.bar(df2021['NEIGHBORHOOD'],df2021['SALE PRICE'], color = 'g')
plt.xticks(rotation=90)
plt.savefig('Bronx Prices Comparision 2021)',bbox_inches='tight')
plt.show()
