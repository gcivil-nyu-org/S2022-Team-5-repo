# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
statenisland2020 = pd.read_csv('2020/2020_staten_island.csv')
statenisland2019 = pd.read_csv('2019/2019_statenisland.csv')
statenisland2018 = pd.read_csv('2018/2018_statenisland.csv')
statenisland2017 = pd.read_csv('2017/2017_statenisland.csv')
statenisland2016 = pd.read_csv('2016/2016_statenisland.csv')

# %%
statenisland2021 = pd.read_csv('2016/2016_statenisland.csv')

# %%
statenisland2020.columns = ['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE', 'SALE PRICE', 'SALE DATE']

# %%
statenisland2016.columns = statenisland2020.columns
statenisland2017.columns = statenisland2020.columns
statenisland2018.columns = statenisland2020.columns
statenisland2019.columns = statenisland2020.columns

# %%
statenisland2021.columns = statenisland2020.columns

# %%
statenisland2016 = statenisland2016.drop(['BOROUGH','BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE','SALE DATE'], axis = 1)

# %%
statenisland2017 = statenisland2017.drop(['BOROUGH','BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE','SALE DATE'], axis = 1)

# %%
statenisland2018 = statenisland2018.drop(['BOROUGH','BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE','SALE DATE'], axis = 1)

# %%
statenisland2019 = statenisland2019.drop(['BOROUGH','BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE','SALE DATE'], axis = 1)

# %%
statenisland2020 = statenisland2020.drop(['BOROUGH','BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE','SALE DATE'], axis = 1)

# %%
statenisland2021 = statenisland2021.drop(['BOROUGH','BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE','SALE DATE'], axis = 1)

# %%
statenisland2016['SALE PRICE'] = statenisland2016['SALE PRICE'].astype(str)
statenisland2017['SALE PRICE'] = statenisland2017['SALE PRICE'].astype(str)
statenisland2018['SALE PRICE'] = statenisland2018['SALE PRICE'].astype(str)
statenisland2019['SALE PRICE'] = statenisland2019['SALE PRICE'].astype(str)
statenisland2020['SALE PRICE'] = statenisland2020['SALE PRICE'].astype(str)

# %%
statenisland2021['SALE PRICE'] = statenisland2021['SALE PRICE'].astype(str)

# %%
statenisland2016['SALE PRICE'] = statenisland2016['SALE PRICE'].apply(lambda x: x.replace(',', ''))
statenisland2017['SALE PRICE'] = statenisland2017['SALE PRICE'].apply(lambda x: x.replace(',', ''))
statenisland2018['SALE PRICE'] = statenisland2018['SALE PRICE'].apply(lambda x: x.replace(',', ''))
statenisland2019['SALE PRICE'] = statenisland2019['SALE PRICE'].apply(lambda x: x.replace(',', ''))
statenisland2020['SALE PRICE'] = statenisland2020['SALE PRICE'].apply(lambda x: x.replace(',', ''))

# %%
statenisland2021['SALE PRICE'] = statenisland2021['SALE PRICE'].apply(lambda x: x.replace(',', ''))

# %%
statenisland2016['SALE PRICE'] = statenisland2016['SALE PRICE'].replace(' ', '0')
statenisland2017['SALE PRICE'] = statenisland2017['SALE PRICE'].replace(' ', '0')
statenisland2018['SALE PRICE'] = statenisland2018['SALE PRICE'].replace(' ', '0')
statenisland2019['SALE PRICE'] = statenisland2019['SALE PRICE'].replace(' ', '0')
statenisland2020['SALE PRICE'] = statenisland2020['SALE PRICE'].replace(' ', '0')

# %%
statenisland2021['SALE PRICE'] = statenisland2021['SALE PRICE'].replace(' ', '0')

# %%
statenisland2016['SALE PRICE'] = statenisland2016['SALE PRICE'].replace(' -   ', '0')
statenisland2017['SALE PRICE'] = statenisland2017['SALE PRICE'].replace(' -   ', '0')
statenisland2018['SALE PRICE'] = statenisland2018['SALE PRICE'].replace(' -   ', '0')
statenisland2019['SALE PRICE'] = statenisland2019['SALE PRICE'].replace(' -   ', '0')
statenisland2020['SALE PRICE'] = statenisland2020['SALE PRICE'].replace(' -   ', '0')

# %%
statenisland2021['SALE PRICE'] = statenisland2021['SALE PRICE'].replace(' -   ', '0')

# %%
statenisland2016['SALE PRICE'] = pd.to_numeric(statenisland2016['SALE PRICE'], errors = 'coerce')
statenisland2017['SALE PRICE'] = pd.to_numeric(statenisland2017['SALE PRICE'], errors = 'coerce')
statenisland2018['SALE PRICE'] = pd.to_numeric(statenisland2018['SALE PRICE'], errors = 'coerce')
statenisland2019['SALE PRICE'] = pd.to_numeric(statenisland2019['SALE PRICE'], errors = 'coerce')
statenisland2020['SALE PRICE'] = pd.to_numeric(statenisland2020['SALE PRICE'], errors = 'coerce')

# %%
statenisland2021['SALE PRICE'] = pd.to_numeric(statenisland2021['SALE PRICE'], errors = 'coerce')

# %%
statenisland2020['SALE PRICE'].isna().sum()
# Out:
# 14151

# %%
statenisland2016['SALE PRICE'].unique()
# Out:
# array([5.2000000e+05, 0.0000000e+00, 1.0000000e+01, ..., 1.1693337e+07,
#        6.9300000e+04,           nan])

# %%
statenisland2016.dropna(inplace = True)
statenisland2017.dropna(inplace = True)
statenisland2018.dropna(inplace = True)
statenisland2019.dropna(inplace = True)
statenisland2020.dropna(inplace = True)

# %%
statenisland2021.dropna(inplace = True)

# %%
statenisland2016['SALE PRICE'] = statenisland2016['SALE PRICE'].astype(float).div(1000000)
df2016 = statenisland2016.groupby(['NEIGHBORHOOD']).sum().reset_index()

# %%
statenisland2017['SALE PRICE'] = statenisland2017['SALE PRICE'].astype(float).div(1000000)
df2017 = statenisland2017.groupby(['NEIGHBORHOOD']).sum().reset_index()

# %%
statenisland2018['SALE PRICE'] = statenisland2018['SALE PRICE'].astype(float).div(1000000)
df2018 = statenisland2018.groupby(['NEIGHBORHOOD']).sum().reset_index()

# %%
statenisland2019['SALE PRICE'] = statenisland2019['SALE PRICE'].astype(float).div(1000000)
df2019 = statenisland2019.groupby(['NEIGHBORHOOD']).sum().reset_index()

# %%
statenisland2020['SALE PRICE'] = statenisland2020['SALE PRICE'].astype(float).div(1000000)
df2020 = statenisland2020.groupby(['NEIGHBORHOOD']).sum().reset_index()

# %%
statenisland2021['SALE PRICE'] = statenisland2021['SALE PRICE'].astype(float).div(1000000)
df2021 = statenisland2021.groupby(['NEIGHBORHOOD']).sum().reset_index()

# %%
plt.figure(figsize=(20,6))
plt.title('Staten Island Prices Comparision 2016')
plt.xlabel('Neighbourhood')
plt.ylabel('Prices in Millions')
plt.bar(df2016['NEIGHBORHOOD'],df2016['SALE PRICE'], color = 'm')
plt.xticks(rotation=90)
plt.savefig('Staten Island Prices Comparision 2016)',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.title('Staten Island Prices Comparision 2017')
plt.xlabel('Neighbourhood')
plt.ylabel('Prices in Millions')
plt.bar(df2017['NEIGHBORHOOD'],df2017['SALE PRICE'], color = 'm')
plt.xticks(rotation=90)
plt.savefig('Staten Island Prices Comparision 2017)',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.title('Staten Island Prices Comparision 2018')
plt.xlabel('Neighbourhood')
plt.ylabel('Prices in Millions')
plt.bar(df2018['NEIGHBORHOOD'],df2018['SALE PRICE'], color = 'm')
plt.xticks(rotation=90)
plt.savefig('Staten Island Prices Comparision 2018)',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.title('Staten Island Prices Comparision 2019')
plt.xlabel('Neighbourhood')
plt.ylabel('Prices in Millions')
plt.bar(df2019['NEIGHBORHOOD'],df2019['SALE PRICE'], color = 'm')
plt.xticks(rotation=90)
plt.savefig('Staten Island Prices Comparision 2019)',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.title('Staten Island Prices Comparision 2020')
plt.xlabel('Neighbourhood')
plt.ylabel('Prices in Millions')
plt.bar(df2020['NEIGHBORHOOD'],df2020['SALE PRICE'], color = 'm')
plt.xticks(rotation=90)
plt.savefig('Staten Island Prices Comparision 2020)',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.title('Staten Island Prices Comparision 2021')
plt.xlabel('Neighbourhood')
plt.ylabel('Prices in Millions')
plt.bar(df2021['NEIGHBORHOOD'],df2021['SALE PRICE'], color = 'm')
plt.xticks(rotation=90)
plt.savefig('Staten Island Prices Comparision 2021)',bbox_inches='tight')
plt.show()
